# %% [markdown]
# # Finding the Roots or Solutions to Non-Linear Equations
#
# Let's say you need to solve the following equation:
#
# $ \large x = 2 e^{-x} \label{eq1}\tag{1}$
#
# First we need to turn this equation into a problem of finding its root(s). This is done by placing the equation into the form $f(x) = 0$. In the case of Eq.($\ref{eq1}$):
#
# $ \large x - 2 e^{-x} = 0 \label{eq2}\tag{2}$
#
# So here, $f(x) = x - 2 e^{-x}$. This problem has now become a root-finding problem, or finding where the function crosses the $x$-axis.
#
# ### Graphing
# Clearly we will be making some graphs in this module... so let's make a graph of the example function from Eq.($\ref{eq2}$). Note there is a more thorough explanation of [how to use *psm_plot.py*](how_to_use_psm_plot.ipynb). This is my own set of functions to make it somewhat easier to use the *matplotlib* plotting library.

# %%
# %matplotlib inline

#from math import *
#import sympy as sympy
import sys
sys.path.append("/home/elemley/engr3703/psm_plot")
###NOTE: Your psm_plot.py will be in a different location...
from psm_plot import *

def f_string():
    fn_string = 'x - 2.0 * exp(-x)'
    #Note this is just so I can have a single definition of a function as a string
    #This is handy for typesetting the function properly on the graph
    return fn_string

def f(x):
    string = f_string()
    #Note the definition of the function is actually in f_string
    #The next line turns the string into an equation and plugs in x !
    tmp = eval(string)
    return tmp

def main():
    #Make a list of x values
    x = np.linspace(0, 5, 100) 
    x = np.linspace(0, 5,100)
    function_name = f_string()
    function_syms = sympy.latex(sympy.sympify(function_name))
    title_base = "Plot of " + "$" + function_syms + "$"
    title = title_base
    filename = "example_plot1.png"
    xlabel = "x"
    ylabel = "f(x)"
    y_func_label = function_name
    Function0Plot111(x,f,xlabel,ylabel,title,filename) #Please see the code in 
        
if __name__ == '__main__':
    main()

# %% [markdown]
# ***So the root of this function is somewhere between 0 and 1.*** We will use this fact below in using various techniques of root finding.

# %% [markdown]
# ## Bracketing Techniques for Root Finding
# In this context *bracketing the root* means that initially we have two values (here I will always call these $a$ and $b$) between which we know the root must lie. Our goal is to find an automated way to figure this out, which might seem difficult, but since we can find $f(a)$ and $f(b)$ and we know that these **should have different signs**... we know the product of $f(a)f(b)$ should be negative, if $a$ and $b$ bracket the root (Note here we are assuming there is only one root... multiple roots are addressed later).
#
# $ \large if~~f(a)f(b)<0,~~and~~a<b,~~then~~a<x_{root}~~and~~b>x_{root}\label{eq3}\tag{3}$
#
#
# ### Bisection
#
# The *bisection* technique takes two $x$ values, $a$ and $b$, which bracket the root, then finds the mid-point of those values, $ x_{root} = \frac{a+b}{2}$. The next step is to determine whether the actual root is between $a$ and $x_{root}$, or between $x_{root}$ and $b$. Based on the results of this determination, new values of $a$ and $b$ are assumed to be the two values of $a$, $b$, or $x_{root}$ that bracket the root. Here are the steps to this algorithm:
#
# 1. Input (or set via code) $a$ and $b$ values believed to bracket the root.
# 2. Determine if $a$ and $b$ do bracket the root.
#    1. Find $f(a)f(b)$ if it is $<0$ $a$ and $b$ do bracket the root.
#    2. Stop the process... need new $a$ or $b$.
# 3. Calculate the current iteration, $i$ value of the root, $\large x_{root_i} = \frac{a+b}{2} \label{eq4}\tag{4}$
# 4. Determine if the root is between $a$ and $x_{root}$ or between $x_{root}$ and $b$.
#    1. Find $f(a)f(x_{root_i})$:
#        1. If $f(a)f(x_{root_i})<0$ then $a$ stays the same, but $b = x_{root_i}$.
#        2. If $f(a)f(x_{root_i})>0$ then $b$ stays the same, but $a = x_{root_i}$.
# 5. If $i>1$ find the *relative fractional error* $\large \epsilon_r = \lvert \frac{x_{root_i} -x_{root_{i-1}}}{x_{root_i}} \rvert \label{eq5}\tag{5}$
#    1. If $i=1$ return to step 3.
#    2. If $i>1$ with a *stopping criterion* of $\epsilon_s$:
#       1. If $\epsilon_r < \epsilon_s$ then stop the process - you have determined the root to the precision requested.
#       2. If If $\epsilon_r > \epsilon_s$ then return to step 3.
#
#
# Here is a visualization of the first four iterations of bisection using the function from Eq.(2) above. The initial values of $a$ and $b$ were chosen to be *0.8* and *0.9*, respectively.
#
# ![image info](./4_iterations_of_bisection.png)
#
# #### Bisection Code
#
# Below you will find code that implements the bisection technique. Please note, there are a lot of extra things in addition to bisection to improve the formatting on the plot of the results.

# %%
import tabulate as tabulate
# %matplotlib inline

from math import *
import sympy as sympy
import sys
sys.path.append("/home/elemley/engr3703/psm_plot")
###NOTE: Your psm_plot.py will be in a different location...
from psm_plot import *

def f_string():
    fn_string = 'x - 2.0 * exp(-x)'
    #Note this is just so I can have a single definition of a function as a string
    #This is handy for typesetting the function properly on the graph
    return fn_string

def f(x):
    string = f_string()
    #Note the definition of the function is actually in f_string
    #The next line turns the string into an equation and plugs in x !
    tmp = eval(string)
    return tmp

def main():
    a = 0.8  # define and a and b (bracketing values)
    b = 0.9
    x_start = a
    x_end = b
    table = [["i","root approx.","rel. error"]]
    err_stop = 1e-3
    root_data = [a,b]
    a_b=[a,b]
    if f(a) * f(b) < 0:
        rel_err = 1.1 * err_stop
        max_iter = 200
        xr_old = (a + b) / 2
        for i in range(0, max_iter):
            xr = (a + b) / 2
            root_data.append(xr)
            if f(a) * f(xr) < 0:
                b = xr
            else:
                a = xr
            if i > 0:
                # calc rel_err here and compare to err_stop
                # if rel_err is less than rel_err stop the loop now
                rel_err = abs((xr-xr_old)/xr)
                table.append([i+1, xr, f"{rel_err:.2e}"])
                if rel_err <= err_stop:
                    break
            else:
                table.append([i+1, xr, "NA"])
                # if it's not put find a new xns (don't forget to store the old value in'
                # xns_old
            xr_old = xr
            a_b.append(a)
            a_b.append(b)
    else:
        print("Your a and b values do not bracket the root")

    #print(tabulate(table,tablefmt="fancy_grid", headers="firstrow"))
    
    x = np.linspace(x_start, x_end, 100)
    print(i)

    function_name = f_string()
    function_syms = sympy.latex(sympy.sympify(function_name))
    title_base = "Plot of " + "$" + function_syms + "$"
    title = title_base
    filename = "4_iterations_of_bisection.png"
    xlabel = "x"
    ylabel = "f(x)"
    root_data_label = "root approximations"
    y_func_label = function_name

    FunctionRootPlot411(x, xlabel, f, ylabel, root_data, root_data_label, title, filename,a_b)

if __name__ == '__main__':
    main()
# Out:
# 6

# %% [markdown]
# ### Regula Falsa (False Position)
#
# The next bracketing technique we will consider is called *Regula Falsa* or *False Position*. This is an improvement over bisection because it takes into account the the relative size of $f(a)$ and $f(b)$. This technique works by using a line from $f(a)$ to $f(b)$, then using the point at which the line crosses the x-axis as the predicted root, $x_{root_i}$.  See the figure below.
#
# ![image info](./4_iterations_of_regula_falsa.png)
#
# The only real difference between bisection and *regula falsa* is the formula to determine the root during each iteration.
#
# $\large x_{root_i} = \frac{a_i f(b_i) - b_i f(a_i)}{f(b_i) - f(a_i)}  \label{eq6}\tag{6}$
#
# Note that $a_i$ and $b_i$ are the bracketing values for the *ith* iteration.
#
# 1. Input (or set via code) $a$ and $b$ values believed to bracket the root.
# 2. Determine if $a$ and $b$ do bracket the root.
#    1. Find $f(a)f(b)$ if it is $<0$ $a$ and $b$ do bracket the root.
#    2. Stop the process... need new $a$ or $b$.
# 3. Calculate the current iteration, $i$ value of the root, $\large x_{root_i} = \frac{a_i f(b_i) - b_i f(a_i)}{f(b_i) - f(a_i)}$
# 4. Determine if the root is between $a$ and $x_{root}$ or between $x_{root}$ and $b$.
#    1. Find $f(a)f(x_{root_i})$:
#        1. If $f(a)f(x_{root_i})<0$ then $a$ stays the same, but $b = x_{root_i}$.
#        2. If $f(a)f(x_{root_i})>0$ then $b$ stays the same, but $a = x_{root_i}$.
# 5. If $i>1$ find the *relative fractional error* $\large \epsilon_r = \lvert \frac{x_{root_i} -x_{root_{i-1}}}{x_{root_i}} \rvert \label{eq5}\tag{5}$
#    1. If $i=1$ return to step 3.
#    2. If $i>1$ with a *stopping criterion* of $\epsilon_s$:
#       1. If $\epsilon_r < \epsilon_s$ then stop the process - you have determined the root to the precision requested.
#       2. If If $\epsilon_r > \epsilon_s$ then return to step 3.
#
# #### False Position Code
# As follows is an implementation of code to use *False Position*. Note the plotting at the end of this code shows a graphical representation of a particular iteration, *i*. You can choose *i* in the function call:
#
# FunctionRootPlot111_regula_falsa(x, xlabel, f, ylabel, root_data, root_data_label, title, filename,a_b,1)
#
# The last argument in this line, $1$, in the example shown, can be modified. Values of this argument that are $<1$ or greater than the number of iterations to achieve a given $\epsilon_s$ will cause the code to fail.

# %%
def f_string():
    fn_string = 'x - 2.0 * exp(-x)'
    #Note this is just so I can have a single definition of a function as a string
    #This is handy for typesetting the function properly on the graph
    return fn_string

def f(x):
    string = f_string()
    #Note the definition of the function is actually in f_string
    #The next line turns the string into an equation and plugs in x !
    tmp = eval(string)
    return tmp

def main():
    a = -1.0  # define and a and b (bracketing values)
    b = 10.0
    x_start = a
    x_end = b
    table = [["i","root approx.","rel. error"]]
    err_stop = 1e-9
    root_data = [a,b]
    a_b=[a,b]
    if f(a) * f(b) < 0:
        rel_err = 1.1 * err_stop
        max_iter = 200
        xr_old = (a*f(b)-b*f(a))/(f(b)-f(a))
        for i in range(0, max_iter):
            xr = (a*f(b)-b*f(a))/(f(b)-f(a))
            root_data.append(xr)
            if f(a) * f(xr) < 0:
                b = xr
            else:
                a = xr
                #(a*f(b)-b*f(a))/(f(b)-f(a))
            if i > 0:
                # calc rel_err here and compare to err_stop
                # if rel_err is less than rel_err stop the loop now
                rel_err = abs((xr-xr_old)/xr)
                table.append([i+1, xr, f"{rel_err:.2e}"])
                if rel_err <= err_stop:
                    break
            else:
                table.append([i+1, xr, "NA"])
                # if it's not put find a new xns (don't forget to store the old value in'
                # xns_old
            xr_old = xr
            a_b.append(a)
            a_b.append(b)
    else:
        print("Your a and b values do not bracket the root")

    #print(tabulate(table,tablefmt="fancy_grid", headers="firstrow"))
    
    x = np.linspace(x_start, x_end, 100)

    function_name = f_string()
    function_syms = sympy.latex(sympy.sympify(function_name))
    title_base = "Plot of " + "$" + function_syms + "$"
    title = title_base
    filename = "single_iteration_of_regula_falsa.png"
    xlabel = "x"
    ylabel = "f(x)"
    root_data_label = "root approximations"
    y_func_label = function_name

    FunctionRootPlot111_regula_falsa(x, xlabel, f, ylabel, root_data, root_data_label, title, filename,a_b,1)
    #print(root_data)

if __name__ == '__main__':
    main()

# %% [markdown]
# ## Open Techniques for Root Finding
# *Open* methods for finding roots rely on one or more initial guesses of where a root is, then proceed to try to converge of the root. These methods can be very fast in finding a root, but they have the possibility of *diverging* as well, meaning the relative fractional error may never meet a stated stopping criterion.
#
#
# ### Newton-Raphson
# Newton-Raphson relies on knowing a function's derivative to estimate where the function will cross the $x$-axis. This is shown graphically below:
#
# ![image info](./single_iteration_of_newton_raphson_img.png)
#
# Here is the algorithm for Newton-Raphson:
#
# 1. Input (or set via code) a value for $x_1$, this is the first estimate of the root.
# 2. Extend a tangent from the function at $f(x_i)$ to the x-axis. This location on the x-axis is the next, $i+1$ root value, or $x_{i+1}$,  $\large x_{i+1} = x_{i} - \frac{f(x_i)}{f'(x_i)} \label{eq7}\tag{7}$
# 3. Find the *relative fractional error* $\large \epsilon_r = \lvert \frac{x_{i+1} -x_i}{x_{i+1}} \rvert \label{eq5}\tag{5}$
#     1. If $\epsilon_r < \epsilon_s$, then stop the process - you have determined the root to the precision requested.
#     2. If $\epsilon_r > \epsilon_s$, then return to step 2.

# %%
def fprime(x):
    tmp = 1.0+2.0*exp(-x)
    return tmp

def f_string():
    fn_string = 'x - 2.0 * exp(-x)'
    #Note this is just so I can have a single definition of a function as a string
    #This is handy for typesetting the function properly on the graph
    return fn_string

def f(x):
    string = f_string()
    #Note the definition of the function is actually in f_string
    #The next line turns the string into an equation and plugs in x !
    tmp = eval(string)
    return tmp

def main():
    a = -1.0  # define and a and b (bracketing values)
    b = 5.0
    x_start = a
    x_end = b
    xi = 4.0
    table = [["i","root approx.","rel. error"]]
    err_stop = 1e-9
    root_data = [xi]
    #a_b=[a,b]
    rel_err = 1.1 * err_stop
    max_iter = 200
    for i in range(0, max_iter):
        xi_plus_1 = xi-f(xi)/fprime(xi)
        root_data.append(xi_plus_1)
        # calc rel_err here and compare to err_stop
        # if rel_err is less than rel_err stop the loop now
        rel_err = abs((xi_plus_1-xi)/xi_plus_1)
        table.append([i+1, xi_plus_1, f"{rel_err:.2e}"])
        if rel_err <= err_stop:
            break
        else:
            table.append([i+1, xi_plus_1, "NA"])
            # if it's not put find a new xns (don't forget to store the old value in'
            # xns_old
        xi = xi_plus_1

        #print(tabulate(table,tablefmt="fancy_grid", headers="firstrow"))
    
    x = np.linspace(x_start, x_end, 100)

    function_name = f_string()
    function_syms = sympy.latex(sympy.sympify(function_name))
    title_base = "Plot of " + "$" + function_syms + "$"
    title = title_base
    filename = "single_iteration_of_newton_raphson.png"
    xlabel = "x"
    ylabel = "f(x)"
    root_data_label = "root approximations"
    y_func_label = function_name

    FunctionRootPlot111_newton_raphson(x, xlabel, f, ylabel, root_data, root_data_label, title, filename,1)
    #print(root_data)

if __name__ == '__main__':
    main()

# %% [markdown]
# ### Secant Method
#
# The Newton-Raphson method is really a method to use a tangent to the curve to find a root. The downside is needing to know *f'.* One remedy is to use two points and instead of using a tangent at a point to approximate the root, to use a secant that joins the two points. In this scheme the point of intersection of the secant and the x-axis is then the next iteration's approximation of the root.
#
# ![image info](./secant1_2.jpg)              ![image info](./secant2_2.jpg)
#
# Here is the algorithm for the Secant Method:
#
# 1. Input (or set via code) a value for $x_1$ and $x_2$, these are the first two estimates of the root (note they do not have to bracket the root),
# 2. Extend a secant line between the function at $f(x_{i-1})$ and at $f(x_{i})$ then extend this line to the x-axis. This location on the x-axis is the next, $i+1$ root value, or $x_{i+1}$,  $\large x_{i+1} = x_{i} - \frac{f(x_i)(x_{i-1}-x_i)}{f(x_{i-1})-f(x_i)}$
# 3. Find the *relative fractional error* $\large \epsilon_r = \lvert \frac{x_{i+1} -x_i}{x_{i+1}} \rvert $
#     1. If $\epsilon_r < \epsilon_s$, then stop the process - you have determined the root to the precision requested.
#     2. If $\epsilon_r > \epsilon_s$, then return to step 2.
#
# Note: In the Secant Method you are replacing *f'(x)* from Newton Raphson with $\large \frac{f(x_{i-1})-f(x_i)}{(x_{i-1}-x_i)}$ which is an approximation of $f'(\frac{x_i+x_{i-1}}{2})$. We will cover more details on this later this semester.

# %% [markdown]
# ### Fixed Point Iteration
#
# Fixed Point iteration does not directly find $x_{root}$, instead the root finding expression, $f(x)=0$ is rewritten as $x=g(x)$ then the intersection of $y=g(x)$ and $y=x$ is found.
#
# As an example consider solving: $f(x)=1.2x^2-3x+4 =0$. There are two possible $g(x)$ functions in this case - just solve for each of $x$'s in the original $f(x)$ expression.
#
# $\large x=\frac{4+1.2x^2}{3} = g_1(x)$ *or*
#
# $\large x=\sqrt{\frac{3x-4}{1.2} } = g_2(x)$.
#
# Note in the figure below, once a $g(x)$ is chosen the actual root, $x_{root}$ will be where $y=g(x)$ and $y=x$ intersect.
#
# ![image info](./fixed_point_1_1.jpg)
#
# Fixed Point iteration uses a single value, $x_1$ to start the process. For the $x_1$ value a line is extended from $g(x_1)$ to $y=x$, which becomes $x_2$. Then for $x_2$ a line is extended from $g(x_2)$ to $y=x$, which becomes $x_3$... this process continues until the relative fractional error goes below a stopping criterion, $\epsilon_s$.
#
# ![image info](./fixed_point_2_1.jpg)
#
# This can be a very quickly converging method... or it might also diverge. The good news is that for any given $g(x)$ one can determine if the process will converge.
#
# $\large \lvert {g'(x)} \rvert < 1$ This is the convergence criterion for a chosen $g(x)$.
#
#
# #### Fixed Point Example
# Solve $f(x) = x e^{0.5x} +1.2 x - 5 = 0$ There is a solution between $x=1$ and $x=2$. Try using all three possible versions of $g(x)$.
#
# Case 1:
#
# $\large x=\frac{5-xe^{0.5x}}{1.2} = g_1(x)$   and   $\large g_1'(x) = \frac{-(e^{0.5x}+0.5xe^{0.5x})}{1.2}$
#
# Now try $x=1$ and $x=2$ to see if the convergence criterion is met:
#
# $\large \lvert g_1'(x=1) \rvert =2.61~~~~~\lvert g_1'(x=2) \rvert =4.53$
#
# The choice of $g_1$ *will not* converge.
#
# Case 2:
#
# $\large x=\frac{5}{e^{0.5x}+1.2} = g_2(x)$   and   $\large g_2'(x) = \frac{-5e^{0.5x}}{2(e^{0.5x}+1.2)^2}$
#
# Now try $x=1$ and $x=2$ to see if the convergence criterion is met:
#
# $\large \lvert g_2'(x=1) \rvert =0.508~~~~~\lvert g_2'(x=2) \rvert =0.443$
#
# The choice of $g_2$ *will* converge!
#
# Case 3:
#
# $\large x=\frac{5-1.2x}{e^{0.5x}} = g_3(x)$   and   $\large g_3'(x) = \frac{-3.7+0.6x}{e^{0.5x}}$
#
# Now try $x=1$ and $x=2$ to see if the convergence criterion is met:
#
# $\large \lvert g_3'(x=1) \rvert =1.88~~~~~\lvert g_3'(x=2) \rvert =0.920$
#
# The choice of $g_3$ *may* converge.
#
# The best choice here would be to use $g_2(x)$.
#
#
# Now we will implement fixed point iteration in code below with the $g_2(x)$ from the example above.

# %%
def g_string():
    #fn_string = "1.2*pow(x,3)+2*pow(x,2)-20*x-10"
    fn_string = "5/(exp(0.5*x)+1.2)"
    return fn_string

def f_string():
    fn_string = "x*exp(0.5*x)+1.2*x -5"
    return fn_string

def f(x):
    string = f_string()
    tmp = eval(string)
    return tmp

def g(x):
    string = g_string()
    tmp = eval(string)
    return tmp

xold = 2.0     #initial guess of x
root_approx = [xold]

err_stop = 1e-5     #adjust as needed...
rel_err = 1.1*err_stop  #set value large enough to start process
count = 0
max_iter = 5

table = [["i","root approx.","rel. error"]]

for i in range(0,max_iter):
    count+=1
    tmp = g(xold)
    xnew = tmp
    root_approx.append(xnew)
    if count > 1:
        rel_err = abs((xnew-xold)/xnew)
        table.append([i + 1, xnew, f"{rel_err:.2e}"])
        if rel_err <= err_stop:
            break
    else:
        table.append([i+1, xnew, "NA"])
        # if it's not put find a new xns (don't forget to store the old value in'
        # xns_old
    xold = xnew

#print(tabulate(table,tablefmt="fancy_grid", headers="firstrow"))

x_start = 1
x_end = 2.5
x = np.linspace(x_start, x_end, 100)

function_name = f_string()
function_syms = sympy.latex(sympy.sympify(function_name))
title_base = "Plot of " + "$" + function_syms + "$"
title = title_base
filename = "fixed_point.png"
xlabel = "x"
ylabel = "f(x)"
root_data_label = "root approximations"
y_func_label = function_name

FunctionRootPlot111(x, xlabel, f, ylabel, root_approx, root_data_label, title, filename)
